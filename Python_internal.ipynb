# %%
''' Imagine a publishing company that markets both book and compact disk version of its work. 
Create a class publication that stores the title and price of a publication. 
From this class derive two classes book which adds a page count and CD which adds a playing time in minutes. 
Each of these three classes should have a getData() function to get its data from the user at the keyboard 
and a putData() function to display the data. Write a python program to test the book and CD classes by 
creating instances of them. Asking the user to fill in the data with getData() and displaying 
the data with putData(). '''

# %%
class Publication:
    def __init__(self, title, price):
        self.title = title
        self.price = price
    
    def getData(self):
        self.title = input("Enter the title of the publication: ")
        self.price = float(input("Enter the price of the publication: "))
    
    def putData(self):
        print(f"Title: {self.title}")
        print(f"Price: ${self.price:.2f}")


class Book(Publication):
    def __init__(self, title, price, page_count):
        super().__init__(title, price)
        self.page_count = page_count
    
    def getData(self):
        super().getData()
        self.page_count = int(input("Enter the number of pages in the book: "))
    
    def putData(self):
        super().putData()
        print(f"Page count: {self.page_count}")


class CD(Publication):
    def __init__(self, title, price, play_time):
        super().__init__(title, price)
        self.play_time = play_time
    
    def getData(self):
        super().getData()
        self.play_time = int(input("Enter the playing time of the CD in minutes: "))
    
    def putData(self):
        super().putData()
        print(f"Playing time: {self.play_time} minutes")


book = Book("", 0.0, 0)
cd = CD("", 0.0, 0)

print("\nEnter data for the book:")
book.getData()

print("\nEnter data for the CD:")
cd.getData()

print("\nBook data:")
book.putData()

print("\nCD data:")
cd.putData()
# Out:
# Enter data for the book:
# Enter the title of the publication:  harpercolins
# Enter the price of the publication:  100
# Enter the number of pages in the book:  300
# Enter data for the CD:
# Enter the title of the publication:  penguine
# Enter the price of the publication:  200
# Enter the playing time of the CD in minutes:  90
# Book data:
# Title: harpercolins
# Price: $100.00
# Page count: 300
#
# CD data:
# Title: penguine
# Price: $200.00
# Playing time: 90 minutes

# %%
''' Define a base class Shape with a method calculate_area() that will be overridden by the derived classes. 
Create three derived classes: Rectangle, Circle, and Triangle, each of which will implement the calculate_area()
method according to their respective formulas. Implement concept of polymorphism '''

# %%
import math

class Shape:
    def calculate_area(self):
        pass

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height
    
    def calculate_area(self):
        return self.width * self.height

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    
    def calculate_area(self):
        return math.pi * self.radius ** 2

class Triangle(Shape):
    def __init__(self, base, height):
        self.base = base
        self.height = height
    
    def calculate_area(self):
        return 0.5 * self.base * self.height

def print_area(shape):
    print(f"The area of the {shape.__class__.__name__} is: {shape.calculate_area()}")

rectangle = Rectangle(5, 10)
circle = Circle(7)
triangle = Triangle(6, 8)

print_area(rectangle)
print_area(circle)
print_area(triangle)
# Out:
# The area of the Rectangle is: 50
# The area of the Circle is: 153.93804002589985
# The area of the Triangle is: 24.0
