# %%
# Create a class account with instance variable acc no and balance ,also create a static variable ROI and
#print value of all its instance and static variable

# %%
class account:
    def __init__(self,acc,balance):
        self.acc=acc
        self.balance=balance
        account.roi=100
    def showdata(self):
        print(self.acc)
        print(self.balance)
        print(account.roi)

# %%
ac=account(1,50)
ac.showdata()
# Out:
# 1
# 50
# 100
