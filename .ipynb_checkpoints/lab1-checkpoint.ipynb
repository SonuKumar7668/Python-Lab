# %%
print("hello ")
# Out:
# hello

# %%
print(56)
# Out:
# 56

# %%
def squart(a):
    return a*a
x=map(squart,[3,4,5,6])
l=list(x)
print(type(x))
print(l)
# Out:
# <class 'map'>
# [9, 16, 25, 36]

# %%
for i in l:
    print(i)
# Out:
# 9
# 16
# 25
# 36

# %%
li=tuple(l)
print(li)
# Out:
# (9, 16, 25, 36)

# %%
aq=[10,20,30,40]
bq=[11,22,33,44]
lis=list(map(lambda a,b:a+b,a,b))
print(lis)
# Out:
# [21, 42, 63, 84]

# %%
def f(x):
    if x>=3:
        return x
t=(1,2,3,4,5,6,7,8,9)
y=filter(f,t)
for i in y:
    print(i,end=" ")
# Out:
# 3 4 5 6 7 8 9

# %%
def f(x):
    if x%2==0:
        return x
# t=(1,2,3,4,5,6,7,8,9)
y=filter(f,t)
for i in y:
    print(i,end=" ")
# Out:
# 2 4 6 8

# %%
a=[eval(i) for i in int(input("enter the list").split(","))]
a3=list(filter(lambda n:(n>=3),a))
print(a3)
# Out:
# enter the list 5 6 7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 a=[eval(i) for i in int(input("enter the list").split(","))]
#       2 a3=list(filter(lambda n:(n>=3),a))
#       3 print(a3)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'

# %%
from functools import reduce
l1=[0,1]
def sum(n,m):
    return n+m
l=reduce(sum,l1)
print(l)
# Out:
# 1

# %%
# Program to filter even numbers and to add those even numbers and generate
