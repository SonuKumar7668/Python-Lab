# %%
class person:
    def __init__(self,name,age):
        self.name=n
        self.age=a

class student(person):
    def __init__ (self,r):
        self.rollno=r

class teacher(person):
    def __(self,s,sub):
        delf.salary=s
        self.subject=sub

class brightstudent(student,teacher):
    def __init__(self,name,age,r,s,sub,points):
        self.p=points
        self.name=name
        self.age=age
        self.r=r
        self.s=s
        self.subject=sub

obj=brightstudent ("amit",23,25,1000,"cs",34)
obj.__dict__
# Out:
# {'p': 34, 'name': 'amit', 'age': 23, 'r': 25, 's': 1000, 'subject': 'cs'}

# %%
class test:
    x=10
    __a=20
    def f1():
        print(test.__a)

print(test.x)
print(test._test__a)
test.f1()
# Out:
# 10
# 20
# 20
