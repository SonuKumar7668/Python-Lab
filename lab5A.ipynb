# %%
class player:
    score=0
    # rounds=0
    def win(self):
        player.score+=5
        # player.rounds+=1

    def lose(self):
        player.score-=2
    def showdata(self,rounds):
        print("Score= ",player.score)
        print("Round = ",rounds)
        # print(player.rounds)

p=player();
rounds=int(input("Enter the number of rounds"))
for i in range(rounds):
    a=int(input("1 for win 0 for lose"))
    if(a==1):
        p.win()
    else:
        p.lose()
p.showdata(rounds)
# Out:
# Enter the number of rounds 5
# 1 for win 0 for lose 1
# 1 for win 0 for lose 1
# 1 for win 0 for lose 0
# 1 for win 0 for lose 1
# 1 for win 0 for lose 1
# Score=  18
# Round =  5
