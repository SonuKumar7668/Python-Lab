# %%
def f1():
    x=5
    print(x)

f1()
# print(x)
# Out:
# 5

# %%
a=10
def f2():
    global a
    print(a)
    a=15
    print(a)

f2()
print(a)
# Out:
# 10
# 15
# 15

# %%
y=10
def f3():
    y=2
    print(y)
    print("global ",globals()['y'])

f3()
print(y)
# Out:
# 2
# global  10
# 10
